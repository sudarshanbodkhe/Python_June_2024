# %% [markdown]
# **File Handling**

# %%
File Name                            Types of File

==============================Structures and Semi-Structured===============================

Text                                  .text

Word                                  .doc or .docx

pdf                                   .pdf

CSV(Excel)                            .csv(Comma seprated value)

Excel                                 .xlsx

json                                  .json

==============================Unstructured===================================================

XML                                   .xml(Image data)

Parquet                               .delta(DE)

Delta                                 .delta(DE)

Image                                 .jpg,.JPEG,.png

Video                                 .mp4

Audio                                 .mp3

# %% [markdown]
# **task**
#
# - Get the package name to read each file

# %% [markdown]
# **How to read the text file**
#
# - In order to read any file,we need 3 points
#
# - Where is the file located: directory or folder name
#
#   - 'C:\Users\Lenovo\Documents\Naresh It'
#
# - What is the file name
#
#     -'mbox-short'
#
# - What is the  extension of file
#
#     - '.txt'

# %%
path=r"C:\Users\Lenovo\Downloads\Data Files\mbox-short.txt"
file=open(path)
file.read()
# Out:
# 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\nReturn-Path: <postmaster@collab.sakaiproject.org>\nReceived: from murder (mail.umich.edu [141.211.14.90])\n\t by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nX-Sieve: CMU Sieve 2.3\nReceived: from murder ([unix socket])\n\t by mail.umich.edu (Cyrus v2.2.12) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nReceived: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])\n\tby flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;\n\tSat, 5 Jan 2008 09:14:15 -0500\nReceived: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])\n\tBY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ; \n\t 5 Jan 2008 09:14:10 -0500\nReceived: from paploo.uhi.ac.uk (localhost [127.0.0.1])\n\tby paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;\n\tSat,  5 Jan 2008 14:10:05 +0000 (GMT)\nMessage-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>\nMime-Version: 1.0\n
# ...

# %%
Character Meaning
--------- ---------------------------------------------------------------
'r'       open for reading (default)
'w'       open for writing, truncating the file first
'x'       create a new file and open it for writing
'a'       open for writing, appending to the end of the file if it exists
'b'       binary mode
't'       text mode (default)
'+'       open a disk file for updating (reading and writing)

# %% [markdown]
# **FileNotFoundError**
#
# - Read the file is availble in that location
#
# - Which we are passing

# %% [markdown]
# **Method-2**
#
# - When in real time different laptop different root foldes
#
# - It is not a good way to provide full path with root directory
#
# - So that we will keep data file in python location itself
#
# - which means both datafile and python file in same location
#
# - Then no need to provide folder name
#
# - Only file name and extensio is enough

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Naresh It\\Python'

# %% [markdown]
# **Method-3**
#
# **Using with Keyword**

# %% [markdown]
# - when we use open and read in different lines
#
# - Python indirectly takes a session approach
#
# - The session will close after some time
#
# - The stored data will not able to use(its gone)
#
# - We need to perform the same operation under session
#
# - By using with keyword

# %%
path="mbox-short.txt"
with open(path) as file:
    data=file.read()

# %%
print(data)

# %% [markdown]
# **Encoding**
#
# - Encoding is the method,to hide the charecters for security purpose
#
# - When ever we read some file we have some special charecters
#
# - To avoid those we will use encoding argument while open the file path
#
# - we have so many encoding methods are there
#
# - utf-8-sig
#
#
# **Mode**
#
# - While opening the file there is a mode argument
#
# - By default Mode='r' which means read
#
# - If you want to write Mode='w'
#
#
#
# **File not found error**
#
# - File not found error means file is not available in the given path
#
# - This is completely our job: This error is made by us only
#
# - Go to that path,check the file name in that location
#
#
# **Permission error**
#
# - The file we are using in python is already open in your laptop
#
# - You might be see or might not able to see
#
# - If you see the file is opened,then close the file locally then start read
#
# - if you dont see the opened file,restart the computer
#
# - Again open only jupyter noteboodk and exicute the cell

# %% [markdown]
# **How to write the file**

# %%
# Take method-2
path="sbox.txt"
file=open(path,mode='w',encoding='utf-8-sig')
data=file.write('Follow the checkpoints')

# %% [markdown]
# - Write the file also same way like read the file
#
# - **Check point number-1**
#
#     - what is the file name,which you want to write something
#
#     - Is that file is existed in your or not
#
#     - Genrally we will give the new name,that is not existed in your laptop
#
# - **Check point number-2**
#
#     - choose the correct mode
#
#     - mode='w':clear the existed data and overwrite with new data
#
#     - mode='a':Dont want clear old data,new data append with old data
#
# - **Check point number-3**
#
#     - For reading we will use read
#
#     - For writting we will use write

# %%
path="mbox-short.txt"
file=open(path,mode='r',encoding='utf-8-sig')

# %%
path="mbox-short.txt"
file=open(path,mode='r',encoding='utf-8-sig')
data=file.read()
for i in data.split():
    print(i)
# Out:
# From
# stephen.marquard@uct.ac.za
# Sat
# Jan
# 5
# 09:14:16
# 2008
# Return-Path:
# <postmaster@collab.sakaiproject.org>
# Received:
# from
# murder
# (mail.umich.edu
# [141.211.14.90])
# by
# frankenstein.mail.umich.edu
# (Cyrus
# v2.3.8)
# with
# LMTPA;
# Sat,
# 05
# Jan
# 2008
# 09:14:16
# -0500
# X-Sieve:
# CMU
# Sieve
# 2.3
# Received:
# from
# murder
# ([unix
# socket])
# by
# mail.umich.edu
# (Cyrus
# v2.2.12)
# with
# LMTPA;
# Sat,
# 05
# Jan
# 2008
# 09:14:16
# -0500
# Received:
# from
# holes.mr.itd.umich.edu
# (holes.mr.itd.umich.edu
# [141.211.14.79])
# by
# flawless.mail.umich.edu
# ()
# with
# ESMTP
# id
# m05EEFR1013674;
# Sat,
# 5
# Jan
# 2008
# 09:14:15
# -0500
# Received:
# FROM
# paploo.uhi.ac.uk
# (app1.prod.collab.uhi.ac.uk
# [194.35.219.184])
# BY
# holes.mr.itd.umich.edu
# ID
# 477F90B0.2DB2F.12494
# ;
# 5
# Jan
# 2008
# 09:14:10
# -0500
# Received:
# from
# paploo.uhi.ac.uk
# (localhost
# [127.0.0.1])
# by
# paploo.uhi.ac.uk
# (Postfix)
# with
# ESMTP
# id
# ...

# %%
path="sbox.txt"
file=open(path,mode='w')
data=file.write("Hello please follow the check points")

# %%
data
# Out:
# 36

# %%
path='ganesh.txt'
file=open(path,mode='w')ej
data=file.write("hey harun what are you doing")
data
# Out:
# 28

# %%
len("hey harun")
# Out:
# 9

# %%
path='ganesh.txt'
file=open(path,mode='r')
data=file.read()
data
# Out:
# 'hey harun what are you doing'

# %%
path='writefile1.txt'
with open(path,mode='w') as file:
    file.write("Hello sudarshan you will data scientist in next 1 year with highest package")

# %%
path='writefile2.txt'
with open(path,mode='w') as file:
    file.write("Hey sudarshan, You will fulfil all the dream of your father and mother")

# %%
path="writefile1.txt"
with open(path,mode='r') as file:
    data=file.read()
print(data)
# Out:
# Hello sudarshan you will data scientist in next 1 year with highest package

# %%
path="statistics.txt"
with open(path,mode='w')as file:
    file.write("statistics is very inmportant for data analysis")

# %%
with open(path,mode='r')as file:
    data=file.read()

# %%
data
# Out:
# 'statistics is very inmportant for data analysis'

# %%
path="writefile2.txt"
with open(path,mode='r') as file2:
    data=file2.read()
print(data)
# Out:
# Hey sudarshan, You will fulfil all the dream of your father and mother

# %%
# You want save outputd in a different folder
# But in same root directory

# Get your python location folder
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Naresh It\\Python'

# %% [markdown]
# **How to create a folder**
#
# **os.makedirs**
#
# - This is method to create folder

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Naresh It\\Python'

# %%
folder_name='outputs'
os.getcwd()+'\\'+folder_name #working (average)
os.getcwd()+'/'+folder_name  #not better
os.getcwd()+f"{folder_name}"  #working

os.path.join(os.getcwd(),folder_name)
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Naresh It\\Python\\outputs'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Naresh It\\Python'

# %% [markdown]
# - Here we created manually folder name:**outputs**
#
# - This folder in same root dirctory

# %%
path=r"C:\Users\Lenovo\Documents\Naresh It\Dataout\sud.txt"
with open(path,mode='w') as file:
    file.write("sudarshan bodkhe patil")

# %% [markdown]
# path=r"C:\Users\Lenovo\Documents\Naresh It\Dataout\sud.txt"
# with open(path,mode='r') as file:
#     data=file.read()
# data

# %% [markdown]
# - step-1:create a folder
#
# - step-2:To create a folder we will use:os.makedir()
#
# - step-3: os.makedirs will take the path
#
#     - the path is: full folder path
#
#     - imagine that if you create a folder what is the full path
#
#     - c:users\\.............................\\foldername
#
# - step-4: Again in this we have two things
#
#     - Current working directory
#
#     - Folder name
#
#     - We are telling to python you concatinate both
#
#
# - step-5: os.path.join will concatinate both current working dir folder name

# %%
import os
cwd=os.getcwd()
cwd
folder_name='Data science'
new_dir=os.path.join(cwd,folder_name)
os.makedirs(new_dir)
print(new_dir)
# Out:
# C:\Users\Lenovo\Documents\Naresh It\Python\Data science

# %%
cwd=os.getcwd()
cwd
folder_name='outputs'
new_dir=os.path.join(cwd,folder_name)
new_dir
os.makedirs(new_dir)

# %%
print(new_dir)
# Out:
# C:\Users\Lenovo\Documents\Naresh It\Python\outputs

# %%
file_name='file1.txt'
os.path.join(new_dir,file_name)
# Out:
# 'C:\\Users\\Lenovo\\Documents\\Naresh It\\Python\\outputs\\file1.txt'

# %%
# In order to create a folder 
# We join th path
# cwd+ folder name

# In order to create the filr
# we join the path
# foldername_dir+filename

# %%
folder_dir=new_dir
file_name='file1.txt'
path=os.path.join(folder_dir,file_name)
with open(path,mode='w') as file:
    file.write("Helllo please follow the checkpoints")

# %%
folder_dir=new_dir
file_name='file1.txt'
path=os.path.join(folder_dir,file_name)
with open(path,mode='r') as file:
    data=file.read()

# %%
data
# Out:
# 'Helllo please follow the checkpoints'

# %%
cwd=os.getcwd()
folder_name='sudarshan patil'
new_dir=os.path.join(cwd,folder_name)
os.makedirs(new_dir)

# %%
file_name='sudarshan1.txt'
folder_name=new_dir
path=os.path.join(folder_name,file_name)
with open(path,mode='w') as file:
    file.write('sudarshan bodkhe patil')

# %%
with open(path,mode='r') as file:
    data=file.read()

# %%
data
# Out:
# 'sudarshan bodkhe patil'

# %% [markdown]
# **What we learnt in this session:**
#
# **1)How to create folder using python**
#
# - To create folder in python we will use:os.makedirs
#
# - first take path of current working directory **cwd=os.getcwd**
#
# - Then give folder name: **eg:folder_name=python**
#
# - Then join current working directory + folder_name using **new_dir=(os.path.join(cwd,folder_name))**
#
# - then use **os.makedirs(new_dir)** python automatically create a folder
#
#
#
# **2)How to create file in this same folder**:
#
# eg.
#
# - first take folder_name=new_dir
#
# - second take file name='file1.txt'
#
# - and then join as **path=os.path.join(folder_name,file_name)**
#
# - Then file will automatically created on that same location

# %% [markdown]
# **Q1)Find the number of lines in m-box short file**

# %%
path="mbox-short.txt"
file=open(path)
count=0
for i in file:
    count+=1
print(count)
# Out:
# 1910

# %% [markdown]
# **Enumerate**
#
# - enumerate is a in built function like zip
#
# - It will give two values
#
#     - one is index of line
#
#     - second is actual line

# %%
ix+1
# Out:
# 1910

# %% [markdown]
# - whenever we defined new variable
#
# - That variable is not using
#
# - with out that variable the code will not work
#
# - that variable we can replace with

# %%
path="mbox-short.txt"
file=open(path)
for ix,line in enumerate(file):
    pass
ix+1
# Out:
# 1910

# %% [markdown]
# **Q2) when you read the data some of the lines are not in allignement**

# %%
path="mbox-short.txt"
file=open(path)
for line in file:
    print(line.strip())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# ...

# %% [markdown]
# **Q3)Get the lines which are starting with form and save in a list**

# %%
path="mbox-short.txt"
file=open(path)
from_list=[]
count=0
for line in file:
    if line.startswith('From'):
        from_list.append(line)
len(from_list)
# Out:
# 54

# %%
from_list
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n',
#  'From: stephen.marquard@uct.ac.za\n',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008\n',
#  'From: louis@media.berkeley.edu\n',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008\n',
#  'From: zqian@umich.edu\n',
# ...

# %% [markdown]
# **Q4) In aabove output we need to remove \n at the end**
#
# - take above output as input
#
# - iterate is apply rstrip
#
# - keep in another list

# %%
list1=[]
for line in from_list:
    list1.append(line.rstrip('\n'))
list1
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...

# %%
# Out:
#   Cell In[53], line 4
#     l1=(map[line.rstrip('\n') for line in file if line.startswith('from'),from_list])
#                               ^
# SyntaxError: invalid syntax
